# %% [markdown]
# # Bellabeat Case Study 📊
#
# ## 1. Introduction
# - อธิบายปัญหาทางธุรกิจ (Business Problem)
# - สรุปวัตถุประสงค์ของโปรเจกต์
#
# ---

# %% [markdown]
# ## 2. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import kagglehub

# %% [markdown]
# ## 3. Data Loading

# %%
# Download dataset and save in 'Data' folder
path = kagglehub.dataset_download("arashnic/fitbit")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\Asus\.cache\kagglehub\datasets\arashnic\fitbit\versions\2

# %%
# Load Fitbit dataset
df = pd.read_csv(r'.\Data\Fitabase Data 3.12.16-4.11.16\dailyActivity_merged.csv')

# Display the first few rows
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...
